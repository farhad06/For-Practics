# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
df=pd.read_csv('general_data.csv')
df
# Out:
#       EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0              1   51        No      Travel_Rarely                   Sales
# 1              2   31       Yes  Travel_Frequently  Research & Development
# 2              3   32        No  Travel_Frequently  Research & Development
# 3              4   38        No         Non-Travel  Research & Development
# 4              5   32        No      Travel_Rarely  Research & Development
# ...          ...  ...       ...                ...                     ...
# 4405        4406   42        No      Travel_Rarely  Research & Development
# 4406        4407   29        No      Travel_Rarely  Research & Development
# 4407        4408   25        No      Travel_Rarely  Research & Development
# 4408        4409   42        No      Travel_Rarely                   Sales
# 4409        4410   40        No      Travel_Rarely  Research & Development
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('general_data.csv')
df.groupby(['Department'])['EmployeeCount'].count()
x=['Human Resources','Research & Development','Sales']
y=[189,2883,1338]
fig=plt.subplots(figsize=(10,4))
plt.xlabel('Department')
plt.ylabel('Number of Employees')
plt.bar(x,y,width=0.4,color='g',label='Number of Employees',edgecolor='black')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('general_data.csv')
df.groupby(['Department'])['DistanceFromHome'].mean()
x=['Human Resources','Research & Development','Sales']
y=[8.253968,9.236212,9.230942]
fig=plt.subplots(figsize=(8,2))
plt.xlabel('Department')
plt.ylabel('Average Distance From Home')
plt.bar(x,y,width=0.4,color='b',label='Distance from Home',edgecolor='black')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('general_data.csv')
df.groupby('Department').EducationField.count()
rd=df[df.Department=='Research & Development']
rd.groupby('EducationField').EmployeeCount.count()
x=['Life Sciences','Medical','Other','Technical Degree']
y=[1320,1089,192,282]
fig=plt.subplots(figsize=(10,4))
plt.xlabel('Education Field')
plt.ylabel('Number of Employees')
plt.bar(x,y,width=0.2,color='r',label='Number of Employees',edgecolor='black')
plt.grid()
plt.legend()
plt.show()

# %%
import pandas as pd
df=pd.read_csv('general_data.csv')
df.groupby('Attrition').EmployeeCount.count()
x=['Yes','No']
y=[711,3699]
fig=plt.subplots(figsize=(8,4))
plt.pie(y,labels=x,shadow=True)
plt.legend()
plt.axis('equal')
plt.show()

# %%
df.groupby('Attrition').Age.agg(['max','min','mean'])
x=['Yes','No']
y=[33.607595,37.561233]
fig=plt.subplots(figsize=(8,4))
plt.xlabel('Attrition')
plt.ylabel('Average Age')
plt.bar(x,y,width=0.2,color='b',label='Average Age',edgecolor='blue')
plt.legend()
plt.grid()
plt.show()

# %%
df.columns
# Out:
# Index(['EmployeeID', 'Age', 'Attrition', 'BusinessTravel', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'Gender', 'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance',
#        'JobInvolvement', 'PerformanceRating'],
#       dtype='object')

# %%
ms=df[df.Attrition=='Yes']
ms.groupby('MaritalStatus').EmployeeCount.count()
x=['Divorced','Married','Single']
y=[99,252,360]
fig=plt.subplots(figsize=(8,4))
plt.xlabel('Marital Status')
plt.ylabel('Number of Employees')
plt.bar(x,y,width=0.4,label='Marital Status',color='r',edgecolor='blue')
plt.legend()
plt.grid()
plt.show()

# %%
ms.groupby('Gender').EmployeeCount.count()
x=['Female','Male']
y=[270,441]
fig=plt.subplots(figsize=(12,6))
plt.pie(y,labels=x,shadow=True)
plt.axis('equal')
plt.legend()
plt.show()

# %%
avg=ms['MonthlyIncome']
avg.mean()
# Out:
# 61682.61603375527

# %%
avg.max()
# Out:
# 198590

# %%
df.groupby('Gender').MonthlyIncome.mean()
x=['Female','Male']
y=[64595.255102,65318.684807]
fig=plt.subplots(figsize=(8,4))
plt.xlabel('Gender')
plt.ylabel('Average Monthly Income')
plt.bar(x,y,width=0.4,label='Monthly Income',color='g',edgecolor='black')
plt.grid()
plt.legend()
plt.show()

# %%
df.groupby('Attrition').PercentSalaryHike.agg(['mean','max','min'])
x=['No','Yes']
y=[15.157340,15.481013]
fig=plt.subplots(figsize=(8,4))
plt.xlabel('Attrition')
plt.ylabel('Percent Salary Hike')
plt.bar(x,y,width=0.2,label='Average Percent Salary Hike',color='b',edgecolor='black')
plt.grid()
plt.legend()
plt.show()

# %%
df.groupby('Attrition').TotalWorkingYears.mean()
x=['No','Yes']
y=[11.860780,8.255289]
fig=plt.subplots(figsize=(8,4))
plt.xlabel('Attrition')
plt.ylabel('Average Total Working Years')
plt.bar(x,y,width=0.1,label='Average Working Years',color='g',edgecolor='blue')
plt.grid()
plt.legend()
plt.show()

# %%
df.groupby('Gender').PerformanceRating.mean()
x=['Female','Male']
y=[3.130952,3.168934]
fig=plt.subplots(figsize=(6,4))
plt.xlabel('Gender')
plt.ylabel('Performance Rating')
plt.bar(x,y,width=0.1,label='Average Performance Rating',color='b',edgecolor='black')
plt.grid()
plt.legend()
plt.show()

# %%
mt=df[df.EducationField=='Marketing']
mt.groupby('Attrition').EmployeeCount.count()
x=['Yes','No']
y=[75,402]
fig=plt.subplots(figsize=(8,4))
plt.xlabel('Attrition')
plt.ylabel('Employees in Marketing')
plt.bar(x,y,width=0.1,label='Number of Marketing Employees',color='r',edgecolor='blue')
plt.grid()
plt.legend()
plt.show()

# %%
ag=df.loc[df.Age==60]
ag.groupby('Attrition').EmployeeCount.count()
# Out:
# Attrition
# No    15
# Name: EmployeeCount, dtype: int64

# %%
df.groupby('Attrition').Age.max()
x=['No','Yes']
y=[60,58]
fig=plt.subplots(figsize=(6,4))
plt.xlabel('Attrition')
plt.ylabel('Maximum Age')
plt.bar(x,y,width=0.1,label='Maximum Age',color='g',edgecolor='blue')
plt.legend()
plt.grid()
plt.show()

# %%
bf=df[df.BusinessTravel=='Travel_Frequently']
bf.groupby('Attrition').EmployeeID.count()
x=['No','Yes']
y=[624,207]
fig=plt.subplots(figsize=(8,4))
plt.xlabel('Attrition')
plt.ylabel('Business Travel Frequency')
plt.bar(x,y,width=0.1,label='Business Travel Frequently',color='b',edgecolor='black')
plt.grid()
plt.legend()
plt.show()

# %%
df.rename({'Education':'Educational Qualifications','DistanceFromHome':'DistanceFromHomeInKm'},axis=1,inplace=True)
df
# Out:
#       EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0              1   51        No      Travel_Rarely                   Sales
# 1              2   31       Yes  Travel_Frequently  Research & Development
# 2              3   32        No  Travel_Frequently  Research & Development
# 3              4   38        No         Non-Travel  Research & Development
# 4              5   32        No      Travel_Rarely  Research & Development
# ...          ...  ...       ...                ...                     ...
# 4405        4406   42        No      Travel_Rarely  Research & Development
# 4406        4407   29        No      Travel_Rarely  Research & Development
# 4407        4408   25        No      Travel_Rarely  Research & Development
# 4408        4409   42        No      Travel_Rarely                   Sales
# 4409        4410   40        No      Travel_Rarely  Research & Development
#
# ...

# %%
import pandas as pd
df=pd.read_csv('general_data.csv')
m=df['DistanceFromHome'].median()
df['DistanceFromHome'].fillna(m,inplace=True)
df
# Out:
#       EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0              1   51        No      Travel_Rarely                   Sales
# 1              2   31       Yes  Travel_Frequently  Research & Development
# 2              3   32        No  Travel_Frequently  Research & Development
# 3              4   38        No         Non-Travel  Research & Development
# 4              5   32        No      Travel_Rarely  Research & Development
# ...          ...  ...       ...                ...                     ...
# 4405        4406   42        No      Travel_Rarely  Research & Development
# 4406        4407   29        No      Travel_Rarely  Research & Development
# 4407        4408   25        No      Travel_Rarely  Research & Development
# 4408        4409   42        No      Travel_Rarely                   Sales
# 4409        4410   40        No      Travel_Rarely  Research & Development
#
# ...

# %%
e=df['Age'].median()
df['Age'].fillna(e,inplace=True)
df
# Out:
#       EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0              1   51        No      Travel_Rarely                   Sales
# 1              2   31       Yes  Travel_Frequently  Research & Development
# 2              3   32        No  Travel_Frequently  Research & Development
# 3              4   38        No         Non-Travel  Research & Development
# 4              5   32        No      Travel_Rarely  Research & Development
# ...          ...  ...       ...                ...                     ...
# 4405        4406   42        No      Travel_Rarely  Research & Development
# 4406        4407   29        No      Travel_Rarely  Research & Development
# 4407        4408   25        No      Travel_Rarely  Research & Development
# 4408        4409   42        No      Travel_Rarely                   Sales
# 4409        4410   40        No      Travel_Rarely  Research & Development
#
# ...

# %%
t=df['TotalWorkingYears'].median()
df['TotalWorkingYears'].fillna(t,inplace=True)
df
# Out:
#       EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0              1   51        No      Travel_Rarely                   Sales
# 1              2   31       Yes  Travel_Frequently  Research & Development
# 2              3   32        No  Travel_Frequently  Research & Development
# 3              4   38        No         Non-Travel  Research & Development
# 4              5   32        No      Travel_Rarely  Research & Development
# ...          ...  ...       ...                ...                     ...
# 4405        4406   42        No      Travel_Rarely  Research & Development
# 4406        4407   29        No      Travel_Rarely  Research & Development
# 4407        4408   25        No      Travel_Rarely  Research & Development
# 4408        4409   42        No      Travel_Rarely                   Sales
# 4409        4410   40        No      Travel_Rarely  Research & Development
#
# ...

# %%
y=df['YearsAtCompany'].median()
df['YearsAtCompany'].fillna(y,inplace=True)
df
# Out:
#       EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0              1   51        No      Travel_Rarely                   Sales
# 1              2   31       Yes  Travel_Frequently  Research & Development
# 2              3   32        No  Travel_Frequently  Research & Development
# 3              4   38        No         Non-Travel  Research & Development
# 4              5   32        No      Travel_Rarely  Research & Development
# ...          ...  ...       ...                ...                     ...
# 4405        4406   42        No      Travel_Rarely  Research & Development
# 4406        4407   29        No      Travel_Rarely  Research & Development
# 4407        4408   25        No      Travel_Rarely  Research & Development
# 4408        4409   42        No      Travel_Rarely                   Sales
# 4409        4410   40        No      Travel_Rarely  Research & Development
#
# ...

# %%
w=df['WorkLifeBalance'].median()
df['WorkLifeBalance'].fillna(w,inplace=True)
df
# Out:
#       EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0              1   51        No      Travel_Rarely                   Sales
# 1              2   31       Yes  Travel_Frequently  Research & Development
# 2              3   32        No  Travel_Frequently  Research & Development
# 3              4   38        No         Non-Travel  Research & Development
# 4              5   32        No      Travel_Rarely  Research & Development
# ...          ...  ...       ...                ...                     ...
# 4405        4406   42        No      Travel_Rarely  Research & Development
# 4406        4407   29        No      Travel_Rarely  Research & Development
# 4407        4408   25        No      Travel_Rarely  Research & Development
# 4408        4409   42        No      Travel_Rarely                   Sales
# 4409        4410   40        No      Travel_Rarely  Research & Development
#
# ...

# %%
import pandas as pd
df=pd.read_csv('general_data.csv')
df.set_index('EmployeeID',inplace=True)
df
df.reset_index(inplace=True)
df
# Out:
#       EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0              1   51        No      Travel_Rarely                   Sales
# 1              2   31       Yes  Travel_Frequently  Research & Development
# 2              3   32        No  Travel_Frequently  Research & Development
# 3              4   38        No         Non-Travel  Research & Development
# 4              5   32        No      Travel_Rarely  Research & Development
# ...          ...  ...       ...                ...                     ...
# 4405        4406   42        No      Travel_Rarely  Research & Development
# 4406        4407   29        No      Travel_Rarely  Research & Development
# 4407        4408   25        No      Travel_Rarely  Research & Development
# 4408        4409   42        No      Travel_Rarely                   Sales
# 4409        4410   40        No      Travel_Rarely  Research & Development
#
# ...

# %%
import pandas as pd
df=pd.read_csv('general_data.csv')
df.replace(to_replace={'Age':{40:20}},value=None)
# Out:
#       EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0              1   51        No      Travel_Rarely                   Sales
# 1              2   31       Yes  Travel_Frequently  Research & Development
# 2              3   32        No  Travel_Frequently  Research & Development
# 3              4   38        No         Non-Travel  Research & Development
# 4              5   32        No      Travel_Rarely  Research & Development
# ...          ...  ...       ...                ...                     ...
# 4405        4406   42        No      Travel_Rarely  Research & Development
# 4406        4407   29        No      Travel_Rarely  Research & Development
# 4407        4408   25        No      Travel_Rarely  Research & Development
# 4408        4409   42        No      Travel_Rarely                   Sales
# 4409        4410   20        No      Travel_Rarely  Research & Development
#
# ...

# %%
df.drop_duplicates(subset='Education',keep='first')
# Out:
#    EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0           1   51        No      Travel_Rarely                   Sales
# 1           2   31       Yes  Travel_Frequently  Research & Development
# 2           3   32        No  Travel_Frequently  Research & Development
# 3           4   38        No         Non-Travel  Research & Development
# 5           6   46        No      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 0                 6          2  Life Sciences              1  Female  ...
# 1                10          1  Life Sciences              1  Female  ...
# 2                17          4          Other              1    Male  ...
# 3                 2          5  Life Sciences              1    Male  ...
# 5                 8          3  Life Sciences              1  Female  ...
#
#    TotalWorkingYears TrainingTimesLastYear YearsAtCompany  \
# ...

# %%
def print_result(x):
    print(type(x))
    print(x)
    print()

# %%
df.apply(print_result,axis=0)
# Out:
# <class 'pandas.core.series.Series'>
# 0    1
# 1    2
# 2    3
# 3    4
# 5    6
# Name: EmployeeID, dtype: int64
#
# <class 'pandas.core.series.Series'>
# 0    51
# 1    31
# 2    32
# 3    38
# 5    46
# Name: Age, dtype: int64
#
# <class 'pandas.core.series.Series'>
# 0     No
# 1    Yes
# 2     No
# 3     No
# 5     No
# Name: Attrition, dtype: object
#
# <class 'pandas.core.series.Series'>
# 0        Travel_Rarely
# 1    Travel_Frequently
# 2    Travel_Frequently
# 3           Non-Travel
# 5        Travel_Rarely
# Name: BusinessTravel, dtype: object
#
# <class 'pandas.core.series.Series'>
# 0                     Sales
# 1    Research & Development
# 2    Research & Development
# 3    Research & Development
# 5    Research & Development
# Name: Department, dtype: object
#
# <class 'pandas.core.series.Series'>
# 0     6
# 1    10
# 2    17
# 3     2
# 5     8
# Name: DistanceFromHome, dtype: int64
#
# <class 'pandas.core.series.Series'>
# 0    2
# 1    1
# 2    4
# 3    5
# ...

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df.nunique()
# Out:
# EmployeeID                 5
# Age                        5
# Attrition                  2
# BusinessTravel             3
# Department                 2
# DistanceFromHome           5
# Education                  5
# EducationField             2
# EmployeeCount              1
# Gender                     2
# JobLevel                   3
# JobRole                    5
# MaritalStatus              2
# MonthlyIncome              5
# NumCompaniesWorked         3
# Over18                     1
# PercentSalaryHike          4
# StandardHours              1
# StockOptionLevel           3
# TotalWorkingYears          5
# TrainingTimesLastYear      4
# YearsAtCompany             4
# YearsSinceLastPromotion    3
# YearsWithCurrManager       5
# EnvironmentSatisfaction    3
# JobSatisfaction            2
# WorkLifeBalance            4
# JobInvolvement             2
# PerformanceRating          2
# dtype: int64
