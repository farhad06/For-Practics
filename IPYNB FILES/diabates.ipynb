# %%
import pandas as pd

# %%
df=pd.read_csv("diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1.0     85.0           66.0             29      0.0  26.6
# 1            1.0     85.0           66.0             29      0.0  26.6
# 2            6.0    148.0           72.0             35      0.0  33.6
# 3            1.0     89.0           66.0             23     94.0  28.1
# 4            0.0    137.0           40.0             35    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0    101.0           76.0             48    180.0  32.9
# 764          2.0    122.0           70.0             27      0.0  36.8
# 765          5.0    121.0           72.0             23    112.0  26.2
# 766          1.0    126.0           60.0              0      0.0  30.1
# 767          1.0     93.0           70.0             31      0.0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome name
# 0                       0.351   31      0.0    a
# ...

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          1.0     85.0           66.0             29      0.0  26.6
# 1          1.0     85.0           66.0             29      0.0  26.6
# 2          6.0    148.0           72.0             35      0.0  33.6
# 3          1.0     89.0           66.0             23     94.0  28.1
# 4          0.0    137.0           40.0             35    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome name
# 0                     0.351   31      0.0    a
# 1                     0.351   31      0.0    b
# 2                     0.627   50      1.0    a
# 3                     0.167   21      0.0    b
# 4                     2.288   33      1.0    a

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763         10.0    101.0           76.0             48    180.0  32.9
# 764          2.0    122.0           70.0             27      0.0  36.8
# 765          5.0    121.0           72.0             23    112.0  26.2
# 766          1.0    126.0           60.0              0      0.0  30.1
# 767          1.0     93.0           70.0             31      0.0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome name
# 763                     0.171   63      0.0  NaN
# 764                     0.340   27      0.0  NaN
# 765                     0.245   30      0.0  NaN
# 766                     0.349   47      1.0  NaN
# 767                     0.315   23      0.0  NaN

# %% [markdown]
# ## cleaning empty cell

# %%
new_df=df.dropna(inplace=True)

# %%
new_df

# %% [markdown]
# # replace empty values

# %%
df.fillna(120,inplace=True)

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1.0     85.0           66.0             29      0.0  26.6
# 1            1.0     85.0           66.0             29      0.0  26.6
# 2            6.0    148.0           72.0             35      0.0  33.6
# 3            1.0     89.0           66.0             23     94.0  28.1
# 4            0.0    137.0           40.0             35    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 159         17.0    163.0           72.0             41    114.0  40.9
# 160          4.0    151.0           90.0             38      0.0  29.7
# 161          7.0    102.0           74.0             40    105.0  37.2
# 162          0.0    114.0           80.0             34    285.0  44.2
# 163          2.0    100.0           64.0             23      0.0  29.7
#
#      DiabetesPedigreeFunction  Age  Outcome name
# 0                       0.351   31      0.0    a
# ...

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome', 'name'],
#       dtype='object')

# %%
df["name"].fillna("Rohit",inplace=True)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1.0     85.0           66.0             29      0.0  26.6
# 1            1.0     85.0           66.0             29      0.0  26.6
# 2            6.0    148.0           72.0             35      0.0  33.6
# 3            1.0     89.0           66.0             23     94.0  28.1
# 4            0.0    137.0           40.0             35    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 159         17.0    163.0           72.0             41    114.0  40.9
# 160          4.0    151.0           90.0             38      0.0  29.7
# 161          7.0    102.0           74.0             40    105.0  37.2
# 162          0.0    114.0           80.0             34    285.0  44.2
# 163          2.0    100.0           64.0             23      0.0  29.7
#
#      DiabetesPedigreeFunction  Age  Outcome name
# 0                       0.351   31      0.0    a
# ...

# %%
df.fillna(0).head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          1.0     85.0           66.0             29      0.0  26.6
# 1          1.0     85.0           66.0             29      0.0  26.6
# 2          6.0    148.0           72.0             35      0.0  33.6
# 3          1.0     89.0           66.0             23     94.0  28.1
# 4          0.0    137.0           40.0             35    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome name
# 0                     0.351   31      0.0    a
# 1                     0.351   31      0.0    b
# 2                     0.627   50      1.0    a
# 3                     0.167   21      0.0    b
# 4                     2.288   33      1.0    a

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 159    False
# 160    False
# 161    False
# 162    False
# 163    False
# Length: 159, dtype: bool

# %%
df.groupby("BMI").BMI.count()
# Out:
# BMI
# 0.0     5
# 19.1    1
# 19.4    1
# 19.6    1
# 19.9    1
#        ..
# 48.8    1
# 49.7    1
# 50.0    1
# 53.2    1
# 55.0    1
# Name: BMI, Length: 113, dtype: int64

# %%
df.agg["Glucose","BloodPressure","Age"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7996/531038807.py in <module>
# ----> 1 df.agg["Glucose","BloodPressure","Age"]
#
# TypeError: 'method' object is not subscriptable

# %%
df.tail().reset_index()
# Out:
#    index  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0    159         17.0    163.0           72.0             41    114.0  40.9
# 1    160          4.0    151.0           90.0             38      0.0  29.7
# 2    161          7.0    102.0           74.0             40    105.0  37.2
# 3    162          0.0    114.0           80.0             34    285.0  44.2
# 4    163          2.0    100.0           64.0             23      0.0  29.7
#
#    DiabetesPedigreeFunction  Age  Outcome name
# 0                     0.817   47      1.0    b
# 1                     0.294   36      0.0    a
# 2                     0.204   45      0.0    b
# 3                     0.167   27      0.0    a
# 4                     0.368   21      0.0    b

# %%
df["SkinThickness"].sort_values()
# Out:
# 84      0
# 61      0
# 33      0
# 129     0
# 124     0
#        ..
# 150    50
# 99     51
# 86     54
# 120    56
# 57     60
# Name: SkinThickness, Length: 159, dtype: int64

# %%
df.sort_index()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1.0     85.0           66.0             29      0.0  26.6
# 1            1.0     85.0           66.0             29      0.0  26.6
# 2            6.0    148.0           72.0             35      0.0  33.6
# 3            1.0     89.0           66.0             23     94.0  28.1
# 4            0.0    137.0           40.0             35    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 159         17.0    163.0           72.0             41    114.0  40.9
# 160          4.0    151.0           90.0             38      0.0  29.7
# 161          7.0    102.0           74.0             40    105.0  37.2
# 162          0.0    114.0           80.0             34    285.0  44.2
# 163          2.0    100.0           64.0             23      0.0  29.7
#
#      DiabetesPedigreeFunction  Age  Outcome name
# 0                       0.351   31      0.0    a
# ...

# %%
df.Age.dtype
# Out:
# dtype('int64')

# %%
df.Insulin.dtype
# Out:
# dtype('float64')
