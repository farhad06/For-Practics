# %%
import pandas as pd

# %%
df=pd.read_csv("student-dataset.csv")

# %%
df
# Out:
#       id               name               nationality                 city  \
# 0      0          Kiana Lor                     China               Suzhou
# 1      1     Joshua Lonaker  United States of America        Santa Clarita
# 2      2      Dakota Blanco  United States of America              Oakland
# 3      3    Natasha Yarusso  United States of America        Castro Valley
# 4      4     Brooke Cazares                    Brazil  São José dos Campos
# ..   ...                ...                       ...                  ...
# 302  302        Austin Haas  United States of America             Columbus
# 303  303    Madison Fithian  United States of America          Los Angeles
# 304  304  Zachary Mulvahill  United States of America          Los Angeles
# 305  305   Eliana Michelsen  United States of America              Oakland
# 306  306    Dane Whittemore                    Canada              Toronto
#
# ...

# %%
df.head(10)
# Out:
#    id              name               nationality                 city  \
# 0   0         Kiana Lor                     China               Suzhou
# 1   1    Joshua Lonaker  United States of America        Santa Clarita
# 2   2     Dakota Blanco  United States of America              Oakland
# 3   3   Natasha Yarusso  United States of America        Castro Valley
# 4   4    Brooke Cazares                    Brazil  São José dos Campos
# 5   5  Rochelle Johnson  United States of America         Indianapolis
# 6   6        Joey Abreu                     China             Shenyang
# 7   7    Preston Suarez                    Brazil            São Paulo
# 8   8          Lee Dong               Philippines               Manila
# 9   9     Maa'iz al-Dia                    Turkey             Istanbul
#
#    latitude  longitude gender  ethnic.group  age  english.grade  math.grade  \
# 0     31.31     120.62      F           NaN   22            3.5         3.7
# ...

# %%
df.tail()
# Out:
#       id               name               nationality         city  latitude  \
# 302  302        Austin Haas  United States of America     Columbus     39.96
# 303  303    Madison Fithian  United States of America  Los Angeles     34.05
# 304  304  Zachary Mulvahill  United States of America  Los Angeles     34.05
# 305  305   Eliana Michelsen  United States of America      Oakland     37.80
# 306  306    Dane Whittemore                    Canada      Toronto     43.67
#
#      longitude gender  ethnic.group  age  english.grade  math.grade  \
# 302     -83.00      M           NaN   20            3.6         3.7
# 303    -118.24      F           NaN   20            3.6         3.9
# 304    -118.24      M           NaN   20            3.2         3.4
# 305    -122.27      F           NaN   23            3.0         2.8
# 306     -79.42      M           NaN   21            3.8         3.2
#
#      sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# ...

# %%
df.count() #show not null values in this data set
# Out:
# id                    307
# name                  307
# nationality           307
# city                  307
# latitude              307
# longitude             307
# gender                307
# ethnic.group            0
# age                   307
# english.grade         307
# math.grade            307
# sciences.grade        307
# language.grade        307
# portfolio.rating      307
# coverletter.rating    307
# refletter.rating      307
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'name', 'nationality', 'city', 'latitude', 'longitude', 'gender',
#        'ethnic.group', 'age', 'english.grade', 'math.grade', 'sciences.grade',
#        'language.grade', 'portfolio.rating', 'coverletter.rating',
#        'refletter.rating'],
#       dtype='object')

# %%
df["gender"].count()
# Out:
# 307

# %%
df["language.grade"].value_counts() #count unique values
# Out:
# 5.0    204
# 4.0     48
# 3.0     31
# 2.0     18
# 1.0      5
# 3.7      1
# Name: language.grade, dtype: int64

# %%
df["age"].value_counts()
# Out:
# 22    93
# 21    71
# 23    71
# 20    35
# 24    29
# 19     4
# 25     3
# 26     1
# Name: age, dtype: int64

# %%
sum_math=df["math.grade"].sum()
print(sum_math)
# Out:
# 1048.2

# %%
mean_science=df["sciences.grade"].mean()
print(mean_science)
# Out:
# 3.4465798045602605

# %%
port_rating=df["portfolio.rating"].max()
print(port_rating)
# Out:
# 5

# %%
port_rating=df["portfolio.rating"].min()
print(port_rating)
# Out:
# 1

# %%
df.loc[df.nationality=="China"] #show data whose nationality is china
# Out:
#       id              name nationality       city  latitude  longitude gender  \
# 0      0         Kiana Lor       China     Suzhou     31.31     120.62      F
# 6      6        Joey Abreu       China   Shenyang     41.79     123.43      M
# 21    21       David Weber       China     Peking     39.93     116.39      M
# 24    24       Sila Nguyen       China       Hebi     35.90     114.19      M
# 61    61      Colin Lemont       China   Shanghai     31.05     121.40      M
# 76    76  Sourinthone Tran       China      Wuhan     30.58     114.27      M
# 162  162    Rebecca Ah Fat       China   Tangshan     37.33     114.70      F
# 176  176          Surya Ky       China   Tangshan     37.33     114.70      M
# 189  189          Emma Kim       China   Hengshui     37.73     115.70      F
# 194  194  Chue Fue Richter       China    Qiqihar     47.34     123.97      M
# 214  214    Christian Chow       China     Handan     36.57     114.53      M
# ...

# %%
df.loc[(df.nationality=="China") & (df.gender=="M")] # show the values whose nationality is china and gender is male
# Out:
#       id              name nationality      city  latitude  longitude gender  \
# 6      6        Joey Abreu       China  Shenyang     41.79     123.43      M
# 21    21       David Weber       China    Peking     39.93     116.39      M
# 24    24       Sila Nguyen       China      Hebi     35.90     114.19      M
# 61    61      Colin Lemont       China  Shanghai     31.05     121.40      M
# 76    76  Sourinthone Tran       China     Wuhan     30.58     114.27      M
# 176  176          Surya Ky       China  Tangshan     37.33     114.70      M
# 194  194  Chue Fue Richter       China   Qiqihar     47.34     123.97      M
# 214  214    Christian Chow       China    Handan     36.57     114.53      M
#
#      ethnic.group  age  english.grade  math.grade  sciences.grade  \
# 6             NaN   22            3.7         3.9             3.6
# 21            NaN   20            3.9         3.9             3.9
# 24            NaN   23            2.8         3.5             3.5
# ...

# %%
df.loc[(df.nationality=="China") | (df.city=="Istanbul")] # show the values whose nationality is china or city is Istanbul
# Out:
#       id              name nationality       city  latitude  longitude gender  \
# 0      0         Kiana Lor       China     Suzhou     31.31     120.62      F
# 6      6        Joey Abreu       China   Shenyang     41.79     123.43      M
# 9      9     Maa'iz al-Dia      Turkey   Istanbul     41.02      28.96      M
# 21    21       David Weber       China     Peking     39.93     116.39      M
# 24    24       Sila Nguyen       China       Hebi     35.90     114.19      M
# 61    61      Colin Lemont       China   Shanghai     31.05     121.40      M
# 76    76  Sourinthone Tran       China      Wuhan     30.58     114.27      M
# 162  162    Rebecca Ah Fat       China   Tangshan     37.33     114.70      F
# 176  176          Surya Ky       China   Tangshan     37.33     114.70      M
# 189  189          Emma Kim       China   Hengshui     37.73     115.70      F
# 194  194  Chue Fue Richter       China    Qiqihar     47.34     123.97      M
# ...

# %%
df.loc[df.nationality.isin(["Japan","Peru"])] # show all the values whose nationality is peru and japan
# Out:
#       id             name nationality       city  latitude  longitude gender  \
# 15    15    Brittany Sath       Japan      Tokyo     35.69     139.75      F
# 20    20       Rojesh Her       Japan      Tokyo     35.69     139.75      M
# 36    36    Daniel Garcia        Peru       Lima    -12.05     -77.05      M
# 37    37    Katrina Saito       Japan      Tokyo     35.69     139.75      F
# 43    43  Kenny Fukushima       Japan      Tokyo     35.69     139.75      M
# 46    46       Alan Trinh       Japan      Tokyo     35.69     139.75      M
# 79    79     Macie Nguyen       Japan      Tokyo     35.69     139.75      F
# 95    95  Danielle Nguyen       Japan      Tokyo     35.69     139.75      F
# 97    97    William Pablo       Japan  Kashiwara     34.58     135.62      M
# 99    99    Antonio Desai       Japan   Kawasaki     35.52     139.72      M
# 164  164       Min Singal       Japan      Tokyo     35.69     139.75      F
# ...

# %%
df.loc[df.age.notnull()]
# Out:
#       id               name               nationality                 city  \
# 0      0          Kiana Lor                     China               Suzhou
# 1      1     Joshua Lonaker  United States of America        Santa Clarita
# 2      2      Dakota Blanco  United States of America              Oakland
# 3      3    Natasha Yarusso  United States of America        Castro Valley
# 4      4     Brooke Cazares                    Brazil  São José dos Campos
# ..   ...                ...                       ...                  ...
# 302  302        Austin Haas  United States of America             Columbus
# 303  303    Madison Fithian  United States of America          Los Angeles
# 304  304  Zachary Mulvahill  United States of America          Los Angeles
# 305  305   Eliana Michelsen  United States of America              Oakland
# 306  306    Dane Whittemore                    Canada              Toronto
#
# ...

# %%
df["ethnic.group"]="Yes"

# %%
df
# Out:
#       id               name               nationality                 city  \
# 0      0          Kiana Lor                     China               Suzhou
# 1      1     Joshua Lonaker  United States of America        Santa Clarita
# 2      2      Dakota Blanco  United States of America              Oakland
# 3      3    Natasha Yarusso  United States of America        Castro Valley
# 4      4     Brooke Cazares                    Brazil  São José dos Campos
# ..   ...                ...                       ...                  ...
# 302  302        Austin Haas  United States of America             Columbus
# 303  303    Madison Fithian  United States of America          Los Angeles
# 304  304  Zachary Mulvahill  United States of America          Los Angeles
# 305  305   Eliana Michelsen  United States of America              Oakland
# 306  306    Dane Whittemore                    Canada              Toronto
#
# ...

# %%
df["english.grade"].sum()-df["math.grade"].sum()
# Out:
# -13.700000000000045

# %%
# df["math.grade"].sum()-df["english.grade"].sum()
# Out:
# 13.700000000000045
