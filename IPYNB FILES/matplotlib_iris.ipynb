# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Iris.csv")

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
first_col=df["SepalLengthCm"]
# first_col
l=[]
for i in first_col:
    l.append(i)

# %%
plt.plot(l)
plt.show()

# %%
plt.bar(l,100)
plt.show()

# %%
plt.pie(l)
plt.show()
